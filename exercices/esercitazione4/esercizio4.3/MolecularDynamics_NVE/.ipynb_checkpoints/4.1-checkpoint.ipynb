# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

output_temp = np.empty(1)
output_temp = np.loadtxt(fname = "output_temp.dat")

x = np.arange(output_temp.size)

#print(output_temp)

plt.errorbar(x,output_temp)
plt.xlabel('measures')
plt.ylabel('T [k]')
plt.grid(True)
plt.show()
# Out:
# [1.89856 1.89344 1.88417 ... 1.88991 1.89278 1.89289]
